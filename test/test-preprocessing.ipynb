# %%
import os
os.chdir("../")

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import json
import cv2
from preprocessing.preprocess import *

# %%
image_path = "test/example_forms/julinka_dotaznik/front_page.jpg"
with open("test/example_forms/julinka_dotaznik/front_page_config.json", 'r') as f:
    config = json.load(f)

# %%
from preprocessing.preprocess import preprocess
from IPython.display import Image

import PIL.Image


image_path = "test/example_forms/julinka_dotaznik/front_page.jpg"
im = cv2.imread(image_path)
img = preprocess(im, config)

display(Image(image_path))

display(PIL.Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=L size=1885x2609 at 0x7FB8BD63B410>

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [8, 10]


# %matplotlib notebook
import matplotlib.pyplot as plt
imgplot = plt.imshow(img)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
